# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split 
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
df = pd.read_csv("House_Prices _Full.csv")
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.drop(['date','street','date', 'sqft_living', 'waterfront','city','country','statezip'],axis = 1,inplace= True)
df
# Out:
#              price  bedrooms  bathrooms  sqft_lot  floors  view  condition  \
# 0     3.130000e+05       3.0       1.50      7912     1.5     0          3
# 1     2.384000e+06       5.0       2.50      9050     2.0     4          5
# 2     3.420000e+05       3.0       2.00     11947     1.0     0          4
# 3     4.200000e+05       3.0       2.25      8030     1.0     0          4
# 4     5.500000e+05       4.0       2.50     10500     1.0     0          4
# ...            ...       ...        ...       ...     ...   ...        ...
# 4595  3.081667e+05       3.0       1.75      6360     1.0     0          4
# 4596  5.343333e+05       3.0       2.50      7573     2.0     0          3
# 4597  4.169042e+05       3.0       2.50      7014     2.0     0          3
# 4598  2.034000e+05       4.0       2.00      6630     1.0     0          3
# 4599  2.206000e+05       3.0       2.50      8102     2.0     0          4
#
#       sqft_above  sqft_basement  yr_built  yr_renovated
# ...

# %%
df.shape
# Out:
# (4600, 11)

# %%
df['yr_built'] = 2014 - df['yr_built']

# %%
df['yr_renovated'] = df['yr_renovated'].apply(lambda x: 0 if (x == 0) else 2014 - x)
df
# Out:
#              price  bedrooms  bathrooms  sqft_lot  floors  view  condition  \
# 0     3.130000e+05       3.0       1.50      7912     1.5     0          3
# 1     2.384000e+06       5.0       2.50      9050     2.0     4          5
# 2     3.420000e+05       3.0       2.00     11947     1.0     0          4
# 3     4.200000e+05       3.0       2.25      8030     1.0     0          4
# 4     5.500000e+05       4.0       2.50     10500     1.0     0          4
# ...            ...       ...        ...       ...     ...   ...        ...
# 4595  3.081667e+05       3.0       1.75      6360     1.0     0          4
# 4596  5.343333e+05       3.0       2.50      7573     2.0     0          3
# 4597  4.169042e+05       3.0       2.50      7014     2.0     0          3
# 4598  2.034000e+05       4.0       2.00      6630     1.0     0          3
# 4599  2.206000e+05       3.0       2.50      8102     2.0     0          4
#
#       sqft_above  sqft_basement  yr_built  yr_renovated
# ...

# %%
X = df.drop(['sqft_lot','floors','yr_renovated','price'],axis =1)
y = df['price']

X
# Out:
#       bedrooms  bathrooms  view  condition  sqft_above  sqft_basement  \
# 0          3.0       1.50     0          3        1340              0
# 1          5.0       2.50     4          5        3370            280
# 2          3.0       2.00     0          4        1930              0
# 3          3.0       2.25     0          4        1000           1000
# 4          4.0       2.50     0          4        1140            800
# ...        ...        ...   ...        ...         ...            ...
# 4595       3.0       1.75     0          4        1510              0
# 4596       3.0       2.50     0          3        1460              0
# 4597       3.0       2.50     0          3        3010              0
# 4598       4.0       2.00     0          3        1070           1020
# 4599       3.0       2.50     0          4        1490              0
#
#       yr_built
# 0           59
# 1           93
# 2           48
# 3           51
# 4           38
# ...        ...
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15,random_state= 42)

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
X_train_scale = ss.fit_transform(X_train)
X_test_scale = ss.transform(X_test)

# %%
linearRegression = linear_model.LinearRegression()

# %%
linearRegression.fit(X_train_scale,y_train)
# Out:
# LinearRegression()

# %%
y_pred_linearRegression = linearRegression.predict(X_test_scale)

# %%
rscore_linearRegression = r2_score(y_test,y_pred_linearRegression)

# %%
print('R2 Linear Regression: {}'.format(rscore_linearRegression))
# Out:
# R2 Linear Regression: 0.16925766668757902

# %%
plt.plot(y_pred_linearRegression,y_pred_linearRegression,c='r')
plt.scatter(y_test,y_test,c='g')
plt.title('Linear Regression')
plt.legend(['y_pred_linearRegression','y_pred'])
