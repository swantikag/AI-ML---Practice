# %% [markdown]
# ##  Multiple Linear Regression
#
# ### Data Preprocessing Steps

# %%
# Importing all the libraries

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# Loading the csv file

df = pd.read_csv("data _Full.csv")

# %%
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
#    yr_renovated                    street       city  statezip country
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3             0           857 170th Pl NE   Bellevue  WA 98008     USA
# 4          1992         9105 170th Ave NE    Redmond  WA 98052     USA

# %%
# To check the missing values

df[df.isnull()].count()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
#checking all the columns through boxPlot

sns.set()
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True,cmap='Blues')
plt.show()

# %%
# sqft_living is higly correlated to sqft_above, and sqft_living and bathrooms as well, therefore we are dropping sqft_living

df.drop(['sqft_living'],axis = 1,inplace=True)

# %%
# Checking how many counts of each type of country we have in our dataset

df.country.value_counts()

# Dropping country column as we have unique value i.e., USA

df.drop('country',axis = 1,inplace=True)

# %%
# Checking city column

plt.figure(figsize=(15,5))
df.city.value_counts().plot.bar()
plt.show()

# %%
# As we can see we have seattle country as most, so we keeping only that data

df = df[df['city'] == 'Seattle']

# %%
# Dropping certain fields

df.drop(['city','street','date','waterfront'],axis = 1,inplace=True)

# %%
# To scale statezip column 

le = LabelEncoder()
df['statezip'] = le.fit_transform(df['statezip'])

# %% [markdown]
# ### Handling Outliers here -

# %%
# To check the outliers of independent variable we are making boxplot of column PRICE

sns.set_theme(style="whitegrid")
sns.boxplot( df['price'])
# Out:
# /home/knoldus/miniconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price'>

# %%
#Here, we are removing the outliers

median = df['price'].median()
std = df['price'].std()
outliers = (df['price'] - median).abs() > std
df[outliers] = np.nan
df = df.dropna()
df = df.reset_index(drop=True)

# %%
# checking how the boxplot is looking now of PRICE column

sns.set_theme(style="whitegrid")
sns.boxplot(df['price'])
# Out:
# /home/knoldus/miniconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price'>

# %%
# To check the outliers of dependent variable we are making boxplot 

sns.set_theme(style="whitegrid")
X_data = df.drop(['price'],axis = 1)
sns.boxplot(data = X_data, orient="h")
# Out:
# <AxesSubplot:>

# %%
#Here, we are removing the outliers of sqft_lot

median = df['sqft_lot'].median()
std = df['sqft_lot'].std()
outliers = (df['sqft_lot'] - median).abs() > std
df['sqft_lot'][outliers] = np.nan
df.fillna(median, inplace=True)

#Here, we are removing the outliers of sqft_above
median = df['sqft_above'].median()
std = df['sqft_above'].std()
outliers = (df['sqft_above'] - median).abs() > std
df['sqft_above'][outliers] = np.nan
df.fillna(median, inplace=True)

# %% [markdown]
# ### Fitting our MLR model to the Training set -

# %%
# Here, we are disturbing our data as X and Y i.e.,(Training and Testing Data)

X = df.drop(['price'],axis = 1)
Y = df[['price']]

# %%
X
# Out:
#       bedrooms  bathrooms  sqft_lot  floors  view  condition  sqft_above  \
# 0          2.0       1.00    6380.0     1.0   0.0        3.0       880.0
# 1          4.0       2.00    6200.0     1.5   0.0        3.0      1520.0
# 2          3.0       1.00    6435.0     1.0   0.0        4.0      1090.0
# 3          3.0       1.75    4861.0     2.0   0.0        5.0      1550.0
# 4          3.0       2.25    4861.0     2.5   0.0        3.0      1470.0
# ...        ...        ...       ...     ...   ...        ...         ...
# 1406       2.0       1.00    4650.0     1.0   0.0        4.0      1290.0
# 1407       3.0       1.00    3330.0     1.5   0.0        4.0      1390.0
# 1408       3.0       1.75    5752.0     1.0   0.0        4.0       940.0
# 1409       3.0       1.75    6360.0     1.0   0.0        4.0      1510.0
# 1410       4.0       2.00    6630.0     1.0   0.0        3.0      1070.0
#
#       sqft_basement  yr_built  yr_renovated  statezip
# 0               0.0    1938.0        1994.0       8.0
# 1               0.0    1945.0        2010.0       8.0
# 2               0.0    1955.0        2009.0       3.0
# 3             690.0    1923.0           0.0       8.0
# 4             280.0    2005.0           0.0       0.0
# ...             ...       ...           ...       ...
# 1406            0.0    1906.0        1990.0       8.0
# 1407          500.0    1901.0           0.0       1.0
# 1408          940.0    1945.0           0.0      15.0
# 1409            0.0    1954.0        1979.0      16.0
# 1410         1020.0    1974.0           0.0      23.0
#
# [1411 rows x 11 columns]

# %%
Y
# Out:
#               price
# 0     490000.000000
# 1     640000.000000
# 2     365000.000000
# 3     750000.000000
# 4     626000.000000
# ...             ...
# 1406  406062.500000
# 1407  486895.000000
# 1408  396166.666667
# 1409  308166.666667
# 1410  203400.000000
#
# [1411 rows x 1 columns]

# %%
#Implementing Liner Regression Model

model = LinearRegression()

# %%
#Splitting the data

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.03, random_state=1)

# %%
# Fitting the model

model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Prediction of Test set results -

# %%
#Prediciting the values

y_pred = model.predict(X_test)  
x_pred = model.predict(X_train)

# %%
#Checking the score

print('Train Score: ', model.score(X_train, y_train))  
print('Test Score: ', model.score(X_test, y_test))
# Out:
# Train Score:  0.3732128038552388
# Test Score:  0.5481959681101467

# %%
df.head(10)
# Out:
#       price  bedrooms  bathrooms  sqft_lot  floors  view  condition  \
# 0  490000.0       2.0       1.00    6380.0     1.0   0.0        3.0
# 1  640000.0       4.0       2.00    6200.0     1.5   0.0        3.0
# 2  365000.0       3.0       1.00    6435.0     1.0   0.0        4.0
# 3  750000.0       3.0       1.75    4861.0     2.0   0.0        5.0
# 4  626000.0       3.0       2.25    4861.0     2.5   0.0        3.0
# 5  495000.0       4.0       1.75    6380.0     1.0   0.0        3.0
# 6  615000.0       3.0       1.75    7291.0     1.0   0.0        4.0
# 7  790000.0       3.0       2.50    4750.0     1.0   0.0        4.0
# 8  650000.0       4.0       2.00    5000.0     1.5   1.0        3.0
# 9  440000.0       2.0       1.00    4850.0     1.0   0.0        4.0
#
#    sqft_above  sqft_basement  yr_built  yr_renovated  statezip
# 0       880.0            0.0    1938.0        1994.0       8.0
# 1      1520.0            0.0    1945.0        2010.0       8.0
# 2      1090.0            0.0    1955.0        2009.0       3.0
# 3      1550.0          690.0    1923.0           0.0       8.0
# 4      1470.0          280.0    2005.0           0.0       0.0
# 5      1130.0          470.0    1959.0        1989.0      14.0
# 6      1360.0         1000.0    1948.0           0.0      17.0
# 7      1220.0          900.0    1951.0        1999.0      10.0
# 8      1640.0          180.0    1945.0        2010.0       8.0
# 9       800.0            0.0    1944.0           0.0       4.0
